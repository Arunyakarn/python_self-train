# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
x = [1,2,3]
y = [1,4,9]
z = [10,5,2]
plt.plot(x,y)
plt.plot(x,z)
plt.title('test plot'.title())
plt.xlabel('x'.title())
plt.ylabel('y and z'.title())
plt.legend(["this is y".title(), "this is y and z".title()])
plt.show()
